# %% [markdown]
# # Python Casting
#
# Casting in Python is the process of converting one data type to another. This is useful when you need to perform operations that require specific data types.
#
# ## Instructions
#
# 1. Read the example code below.
# 2. Modify the code to include a new variable with a different data type and cast it to another type.
# 3. Run the code to see the output.
#
# ## Challenge
#
# Write a Python program that declares variables of different data types, casts them to other types, and prints their values.
#
# ---
#
# > **Note**: Be cautious when casting, as some conversions may result in loss of precision or unexpected behavior.

# %%
# Write your code here
x = int(3.14)     # Convert float to int
y = float('5')      # Convert string to float
z = str(5)        # Convert int to string
print(x)
print(y)
print(z)

# %%
# Output cell (leave empty for now)
