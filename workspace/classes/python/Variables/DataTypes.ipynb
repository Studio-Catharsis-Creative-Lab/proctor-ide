# %% [markdown]
# # Python Data Types
#
# Python has several built-in data types that are used to store different kinds of information. Understanding these data types is essential for writing effective Python code.
#
# ## Instructions
#
# 1. Read the example code below.
# 2. Modify the code to include a new variable with a different data type.
# 3. Run the code to see the output.
#
# ## Challenge
#
# Write a Python program that declares variables of different data types and prints their values.
#
# ---
#
# > **Note**: Each data type has specific methods and operations that can be performed on it. Always choose the appropriate data type for your use case.

# %%
# Write your code here
x = 5          # int
y = 3.14       # float
z = 1 + 2j     # complex
print(x)
print(y)
print(z)

# %%
# Output cell (leave empty for now)
