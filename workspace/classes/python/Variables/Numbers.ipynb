# %% [markdown]
# # Python Numbers
#
# Python supports three numeric types: `int`, `float`, and `complex`. These types are used to represent different kinds of numbers in your code.
#
# ## Instructions
#
# 1. Read the example code below.
# 2. Modify the code to include a new variable with a different numeric type.
# 3. Run the code to see the output.
#
# ## Challenge
#
# Write a Python program that declares variables of different numeric types and prints their values.
#
# ---
#
# > **Note**: Python automatically handles type conversion in many cases, but explicit conversion can be useful for ensuring the correct data type.

# %%
# Write your code here
x = 5          # int
y = 3.14       # float
z = 1 + 2j     # complex
print(x)
print(y)
print(z)

# %%
# Output cell (leave empty for now)
