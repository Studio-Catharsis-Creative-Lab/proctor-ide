# %% [markdown]
# # Python Booleans
#
# Booleans in Python are a data type that can have one of two values: `True` or `False`. They are used to represent the truth value of an expression.
#
# ## Instructions
#
# 1. Read the example code below.
# 2. Modify the code to include a new boolean variable and perform a boolean operation.
# 3. Run the code to see the output.
#
# ## Challenge
#
# Write a Python program that declares boolean variables, performs boolean operations, and prints their values.
#
# ---
#
# > **Note**: Booleans are often used in conditional statements and loops to control the flow of a program.

# %%
# Write your code here
x = 5
y = 3
print(x == y)  # False
print(x > y)   # True

# %%
# Output cell (leave empty for now)
