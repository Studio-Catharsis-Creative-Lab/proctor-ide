# %% [markdown]
# # Python Operators
#
# Operators in Python are special symbols that perform arithmetic, comparison, logical, and other operations on operands. They are essential for performing calculations and making decisions in your code.
#
# ## Instructions
#
# 1. Read the example code below.
# 2. Modify the code to include a new operator and perform an operation.
# 3. Run the code to see the output.
#
# ## Challenge
#
# Write a Python program that declares variables, performs operations using different operators, and prints their values.
#
# ---
#
# > **Note**: Understanding operators is crucial for writing efficient and effective Python code. Always use the appropriate operator for the task at hand.

# %%
# Write your code here
x = 5
y = 3
print(x + y)  # Addition
print(x - y)  # Subtraction
print(x * y)  # Multiplication
print(x / y)  # Division
print(x % y)  # Modulus
print(x ** y) # Exponentiation
print(x // y) # Floor division

# %%
# Output cell (leave empty for now)
