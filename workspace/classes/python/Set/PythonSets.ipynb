# %% [markdown]
# # Python Sets
#
# Sets in Python are unordered collections of unique elements. They are useful for removing duplicates and performing mathematical set operations.
#
# ## Instructions
#
# 1. Read the example code below.
# 2. Modify the code to include a new set and perform a set operation.
# 3. Run the code to see the output.
#
# ## Challenge
#
# Write a Python program that declares sets, performs set operations, and prints their values.
#
# ---
#
# > **Note**: Sets are mutable, but their elements must be immutable. Use sets when you need to store unique elements and perform set operations.

# %%
# Write your code here
my_set = {1, 2, 3}  # Create a set

set1 = {1, 2, 3}
set2 = {3, 4, 5}
union_set = set1 | set2  # Union of set1 and set2
print(union_set)       # Output: {1, 2, 3, 4, 5}

intersection_set = set1 & set2  # Intersection of set1 and set2
print(intersection_set)           # Output: {3}

difference_set = set1 - set2  # Elements in set1 but not in set2
print(difference_set)         # Output: {1, 2}

symmetric_difference_set = set1 ^ set2  # Elements in either set1 or set2 but not both
print(symmetric_difference_set)          # Output: {1, 2, 4, 5}

# %%
# Output cell (leave empty for now)
