# %% [markdown]
# # Python Functions
#
# Define and call functions with parameters and return values.
#
# ## Instructions
#
# 1. Read the challenge below.
# 2. Write your solution in the **code** cell.
# 3. Run it and check results in the **output** cell (or run output below the editor).
#
# ## Challenge / prompt
#
# _Complete the exercise described by your instructor, or add your own goal here._

# %%
# Your solution here
pass

# %%
# Output / scratch (optional)
