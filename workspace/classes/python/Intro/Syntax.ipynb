# %% [markdown]
# # Python Syntax
#
# Python syntax is the set of rules that define how a Python program is written and interpreted. Unlike many other languages, Python relies heavily on whitespace (indentation) to define code blocks. This makes Python code highly readable and consistent.
#
# ## Instructions
#
# 1. Read the example code below.
# 2. Modify the code to print your name instead of "Hello, World!".
# 3. Run the code to see the output.
#
# ## Challenge
#
# Write a Python program that prints "Hello, [Your Name]!" to the console.
#
# ---
#
# > **Note**: The above example shows correct indentation and comment usage. Always follow these conventions for clean, maintainable code.

# %%
# Write your code here
print("Hello, World!")

# %%
# Output cell (leave empty for now)
