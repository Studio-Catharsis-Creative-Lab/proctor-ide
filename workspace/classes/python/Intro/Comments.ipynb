# %% [markdown]
# # Python Comments
#
# Comments in Python are used to explain code and make it more readable. They are ignored by the Python interpreter.
#
# ## Instructions
#
# 1. Read the example code below.
# 2. Add a comment to explain what each line does.
# 3. Run the code to see the output.
#
# ## Challenge
#
# Write a Python program that prints "Hello, World!" to the console and add comments to explain each line.
#
# ---
#
# > **Note**: Comments should be used sparingly and only when necessary to explain complex logic or intent.

# %%
# Write your code here
print("Hello, World!")

# %%
# Output cell (leave empty for now)
